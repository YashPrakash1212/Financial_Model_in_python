# %%
pip install Matplotlib

# %%
import matplotlib.pyplot as plt

# %%
import numpy as np

# %%
x = [1, 2, 3, 4, 5]
y1 = np.square(x)
y2 = np.sqrt(x)
plt.hist(x, y1)
plt.hist(x, y2)
plt.title("My First plot")
plt.show()

# %% [markdown]
# ### Plotting Two Linear Equations
#
# To plot two linear equations on the same graph, we will define a range of `x` values, calculate the corresponding `y` values for each equation, and then call `plt.plot()` multiple times before `plt.show()`.

# %%
# Define a range of x values
x_linear = np.linspace(-10, 10, 400)

# Define two linear equations
y_linear_1 = 2 * x_linear + 3  # Example: y = 2x + 3
y_linear_2 = -0.5 * x_linear + 5 # Example: y = -0.5x + 5

# Create the plot
plt.figure(figsize=(8, 6))
plt.plot(x_linear, y_linear_1, label='y = 2x + 3', color='blue')
plt.plot(x_linear, y_linear_2, label='y = -0.5x + 5', color='red', linestyle='--')

# Add title and labels
plt.title('Two Linear Equations on the Same Plot')
plt.xlabel('x-axis')
plt.ylabel('y-axis')
plt.grid(True)
plt.axhline(0, color='black', linewidth=0.5)
plt.axvline(0, color='black', linewidth=0.5)
plt.legend()
plt.show()

# %%
data = np.random.normal(loc=0, scale=1, size=1000)

# Create the histogram
plt.figure(figsize=(8, 6))
plt.hist(data, bins=30, edgecolor='black')

# Add title and labels
plt.title('Normal Distribution')
plt.xlabel('Value')
plt.ylabel('Frequency')
plt.grid(True, linestyle='--', alpha=0.7)
plt.show()
